# %% [markdown]
# <a href="https://colab.research.google.com/github/GalkaKG/AI-for-developers/blob/main/AI_agents_and_workflows/Project/research_assistant_multiagent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔬 AI Research Assistant – Multi-Agent Workflow
#
# ## Scenario
#
# This notebook implements a **Multi-Agent Research Assistant** that automates the research-to-report pipeline:
#
# | Agent | Role | Tools Used |
# |-------|------|------------|
# | **Researcher Agent** | Searches the web and Wikipedia to gather comprehensive, up-to-date information on a given topic | DuckDuckGo Search, Wikipedia Search |
# | **Writer Agent** | Synthesises the raw findings into a polished, structured research report | *(LLM only)* |
#
# ## Workflow
#
# ```
# START ──► researcher_node ──► writer_node ──► [INTERRUPT] ──► human_review_node ──► END
#                                                                        │
#                                                               (if revision needed)
#                                                                        │
#                                                                writer_node ◄──┘
# ```
#
# **Human-in-the-Loop (HITL):** Before the final report is approved, the graph pauses and asks the human reviewer to either approve the draft or request revisions. The workflow loops until the reviewer is satisfied (max 3 revision rounds).
#
# **Memory:** A `MemorySaver` checkpointer persists the full conversation state across HITL interrupts, enabling seamless resumption.
#
# ---
# **Assignment:** AI Agents and Workflows for Developers – April 2026 Individual Project
# **Model:** OpenAI GPT-4o-mini
# **Framework:** LangGraph + LangChain

# %%
# Install required packages
# !pip install -q \
    "langchain>=0.3.0" \
    "langchain-openai>=0.2.0" \
    "langchain-community>=0.3.0" \
    "langgraph>=0.2.0" \
    "duckduckgo-search>=6.0.0" \
    ddgs \
    wikipedia
print("All packages installed successfully.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 2.1 MB/s eta 0:00:00
# All packages installed successfully.

# %% [markdown]
# ## Imports & Configuration

# %%
import os
import uuid
from typing import TypedDict, Annotated, List, Literal

from langchain_core.messages import (
    BaseMessage, HumanMessage, AIMessage,
    SystemMessage, ToolMessage
)
from langchain_openai import ChatOpenAI
from langchain_community.tools import DuckDuckGoSearchRun, WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import MemorySaver

print("Imports loaded successfully.")
# Out:
# /usr/local/lib/python3.12/dist-packages/langgraph/cache/base/__init__.py:8: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer
# Imports loaded successfully.

# %%
# ── API Key Setup ────────────────────────────────────────────────────────────
# In Google Colab: add OPENAI_API_KEY to Secrets (key icon in left sidebar)
# Locally: set it as an environment variable before running
# DO NOT paste your key directly into this cell!

try:
    from google.colab import userdata
    os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
    print("API key loaded from Colab Secrets.")
except Exception:
    if not os.environ.get("OPENAI_API_KEY"):
        raise EnvironmentError(
            "OPENAI_API_KEY not found. "
            "Set it as a Colab Secret or environment variable."
        )
    print("API key loaded from environment variable.")

# DuckDuckGo and Wikipedia require no API keys
print("DuckDuckGo & Wikipedia: no API key required.")
# Out:
# API key loaded from Colab Secrets.
# DuckDuckGo & Wikipedia: no API key required.

# %% [markdown]
# ## State Definition

# %%
class ResearchState(TypedDict):
    """Shared state passed between all agents in the graph."""
    user_request:   str                                    # Original topic from the user
    search_results: str                                    # Raw findings from Researcher
    draft_report:   str                                    # Current draft from Writer
    final_report:   str                                    # Approved final report
    human_feedback: str                                    # Reviewer's feedback
    revision_count: int                                    # Number of revision cycles
    messages: Annotated[List[BaseMessage], add_messages]   # Accumulated conversation log

print("ResearchState defined.")
# Out:
# ResearchState defined.

# %% [markdown]
# ## Tools Setup

# %%
# Tool 1 – DuckDuckGo web search (no API key required)
ddg_search = DuckDuckGoSearchRun(
    name="web_search",
    description="Search the web with DuckDuckGo for current news and facts."
)

# Tool 2 – Wikipedia (no API key required)
wiki_api = WikipediaAPIWrapper(top_k_results=2, doc_content_chars_max=3000)
wikipedia_tool = WikipediaQueryRun(
    api_wrapper=wiki_api,
    name="wikipedia_search",
    description="Search Wikipedia for comprehensive background knowledge."
)

TOOLS = [ddg_search, wikipedia_tool]
TOOLS_DICT = {t.name: t for t in TOOLS}

print(f"Tools ready: {[t.name for t in TOOLS]}")
# Out:
# Tools ready: ['web_search', 'wikipedia_search']

# %% [markdown]
# ## LLM Instances

# %%
# Researcher uses tool-calling; Writer only needs text generation
researcher_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
researcher_with_tools = researcher_llm.bind_tools(TOOLS)

writer_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)

print("LLM instances ready.")
# Out:
# LLM instances ready.

# %% [markdown]
# ## Agent Nodes

# %%
# ─────────────────────────────────────────────────────────────
# AGENT 1 – Researcher
# System prompt: expert researcher who uses DuckDuckGo + Wikipedia
# ─────────────────────────────────────────────────────────────
def researcher_node(state: ResearchState) -> dict:
    print("\n" + "=" * 55)
    print("[Researcher Agent] Gathering information...")
    print("=" * 55)

    system_prompt = (
        "You are an expert research agent.\n"
        "Use 'web_search' for current facts and recent developments.\n"
        "Use 'wikipedia_search' for background knowledge and definitions.\n"
        "Make at least 2 searches (one of each tool) for thorough coverage.\n"
        "After searching, summarise ALL findings in a detailed, structured way."
    )

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=f"Research this topic thoroughly: {state['user_request']}")
    ]

    for _ in range(8):  # max tool-call iterations
        response = researcher_with_tools.invoke(messages)
        messages.append(response)

        if not response.tool_calls:
            print("  [Researcher] Research complete.")
            break

        for tc in response.tool_calls:
            tool_name = tc["name"]
            query = str(list(tc["args"].values())[0])
            print(f"  -> {tool_name}: '{query[:70]}'")
            try:
                result = TOOLS_DICT[tool_name].invoke(tc["args"])
                result_str = str(result)
            except Exception as e:
                result_str = f"Tool error: {e}"
            messages.append(ToolMessage(content=result_str, tool_call_id=tc["id"]))

    final_ai = next(
        (m for m in reversed(messages) if isinstance(m, AIMessage) and not m.tool_calls),
        None
    )
    summary = final_ai.content if final_ai else "No research summary available."

    return {
        "search_results": summary,
        "messages": [AIMessage(content=f"Research done: {state['user_request'][:60]}")]
    }


# ─────────────────────────────────────────────────────────────
# AGENT 2 – Writer
# System prompt: expert technical writer who creates/revises reports
# ─────────────────────────────────────────────────────────────
def writer_node(state: ResearchState) -> dict:
    revision_count = state.get("revision_count", 0)
    is_revision = revision_count > 0

    print("\n" + "=" * 55)
    label = f"Revising report (revision #{revision_count})" if is_revision else "Creating initial report"
    print(f"[Writer Agent] {label}...")
    print("=" * 55)

    if is_revision:
        feedback = state.get("human_feedback", "")
        prompt = (
            f"You are an expert technical writer. Revise the report based on the reviewer's feedback.\n\n"
            f"ORIGINAL REPORT:\n{state.get('draft_report', '')}\n\n"
            f"REVIEWER FEEDBACK:\n{feedback}\n\n"
            f"RESEARCH DATA:\n{state.get('search_results', '')}\n\n"
            f"Address ALL feedback points. Keep the professional structure."
        )
    else:
        prompt = (
            f"You are an expert technical writer. Create a comprehensive research report.\n\n"
            f"TOPIC: {state['user_request']}\n\n"
            f"RESEARCH FINDINGS:\n{state.get('search_results', '')}\n\n"
            f"Format the report with these sections:\n"
            f"# Research Report: [Title]\n"
            f"## Executive Summary\n"
            f"## Key Findings (3-5 bullet points)\n"
            f"## Detailed Analysis (3-4 paragraphs)\n"
            f"## Conclusions & Implications\n"
        )

    response = writer_llm.invoke([HumanMessage(content=prompt)])
    print("  [Writer] Draft ready.")

    return {
        "draft_report": response.content,
        "messages": [AIMessage(content="Report draft created/updated.")]
    }


# ─────────────────────────────────────────────────────────────
# Human Review Node  (runs AFTER the HITL interrupt is resolved)
# ─────────────────────────────────────────────────────────────
def human_review_node(state: ResearchState) -> dict:
    feedback = state.get("human_feedback", "").strip().lower()
    revision_count = state.get("revision_count", 0)

    APPROVED = {"approve", "approved", "yes", "ok", "looks good",
                "good", "accept", "accepted", "fine", "great", "perfect", "lgtm"}

    is_approved = (
        feedback in APPROVED
        or any(kw in feedback for kw in ["approve", "looks good", "accept"])
        or revision_count >= 3
    )

    if is_approved:
        print("\n  [Human Review] Report APPROVED. Finalising...")
        return {"final_report": state["draft_report"]}
    else:
        new_count = revision_count + 1
        print(f"\n  [Human Review] Revision #{new_count} requested.")
        return {
            "revision_count": new_count,
            "human_feedback": state.get("human_feedback", "")
        }


def route_after_review(state: ResearchState) -> str:
    """Conditional router: approved -> END, revision -> writer_node."""
    return END if state.get("final_report") else "writer_node"


print("Agent nodes defined.")
# Out:
# Agent nodes defined.

# %% [markdown]
# ## Graph Construction

# %%
# Persistent checkpointer (MemorySaver keeps state across HITL interrupts)
memory_checkpointer = MemorySaver()

builder = StateGraph(ResearchState)

# Register nodes
builder.add_node("researcher_node", researcher_node)
builder.add_node("writer_node",     writer_node)
builder.add_node("human_review_node", human_review_node)

# Edges
builder.add_edge(START, "researcher_node")
builder.add_edge("researcher_node", "writer_node")
builder.add_edge("writer_node", "human_review_node")
builder.add_conditional_edges("human_review_node", route_after_review)

# Compile with MemorySaver + HITL interrupt before human_review_node
graph = builder.compile(
    checkpointer=memory_checkpointer,
    interrupt_before=["human_review_node"]
)

print("Graph compiled successfully.")
print("Flow: START -> researcher -> writer -> [INTERRUPT] -> human_review -> END")
print("      (or, if revision requested)  -> writer -> [INTERRUPT] -> ...")
# Out:
# Graph compiled successfully.
# Flow: START -> researcher -> writer -> [INTERRUPT] -> human_review -> END
#       (or, if revision requested)  -> writer -> [INTERRUPT] -> ...

# %% [markdown]
# ## Core Function: `execute_workflow`

# %%
def execute_workflow(user_request: str) -> str:
    """
    Run the multi-agent research workflow with interactive Human-in-the-Loop review.

    The graph pauses before human_review_node on each iteration. The reviewer
    types 'approve' (or similar) to finalise, or provides revision instructions
    to trigger another writer pass.

    Args:
        user_request: The research topic or question.

    Returns:
        The final approved research report as a string.
    """
    thread_id = str(uuid.uuid4())
    config = {"configurable": {"thread_id": thread_id}}

    initial_state = {
        "user_request":   user_request,
        "search_results": "",
        "draft_report":   "",
        "final_report":   "",
        "human_feedback": "",
        "revision_count": 0,
        "messages":       []
    }

    print("\n" + "#" * 60)
    print(f"  RESEARCH WORKFLOW  |  {thread_id[:8]}")
    print(f"  Topic: {user_request}")
    print("#" * 60)

    # ── Phase 1: run agents until HITL interrupt ────────────────
    print("\n[Phase 1] Launching Researcher and Writer agents...")
    for _ in graph.stream(initial_state, config, stream_mode="values"):
        pass

    # ── HITL loop ───────────────────────────────────────────────
    review_round = 0
    while True:
        snapshot = graph.get_state(config)
        if not snapshot.next:       # graph finished
            break

        review_round += 1
        draft = snapshot.values.get("draft_report", "(no draft)")

        print("\n" + "-" * 60)
        print(f"  HUMAN-IN-THE-LOOP REVIEW  (round {review_round})")
        print("-" * 60)
        print(draft)
        print("-" * 60)
        print("\nType 'approve' to finalise, or enter revision instructions:")

        human_input = input("Your feedback: ").strip() or "approve"

        graph.update_state(config, {"human_feedback": human_input})

        print(f"\n[Phase {review_round + 1}] Resuming graph...")
        for _ in graph.stream(None, config, stream_mode="values"):
            pass

    final = graph.get_state(config).values.get(
        "final_report", "Workflow ended without producing a final report."
    )

    print("\n" + "#" * 60)
    print("  WORKFLOW COMPLETE – FINAL REPORT")
    print("#" * 60)
    print(final)
    return final


print("execute_workflow() defined.")
# Out:
# execute_workflow() defined.

# %% [markdown]
# ## Visualise the Graph

# %%
try:
    from IPython.display import Image, display
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception as exc:
    print(f"Graph visualisation unavailable ({exc}); continuing without it.")

# %% [markdown]
# ## Test Helper (simulates HITL without blocking `input()`)

# %%
def run_workflow_test(
    user_request: str,
    feedback_sequence: list,
    test_name: str = ""
) -> str:
    """
    Automated variant of execute_workflow for test cases.
    Instead of prompting the user, it pops values from feedback_sequence
    at each HITL checkpoint (defaults to 'approve' when the list is exhausted).

    Args:
        user_request:      Research topic.
        feedback_sequence: Ordered list of feedback strings to inject.
        test_name:         Optional label for display.

    Returns:
        The final approved report string.
    """
    if test_name:
        print("\n" + "*" * 60)
        print(f"  {test_name}")
        print("*" * 60)

    thread_id = str(uuid.uuid4())
    config = {"configurable": {"thread_id": thread_id}}

    initial_state = {
        "user_request":   user_request,
        "search_results": "",
        "draft_report":   "",
        "final_report":   "",
        "human_feedback": "",
        "revision_count": 0,
        "messages":       []
    }

    print(f"\nTopic: {user_request}")
    print(f"Planned feedback sequence: {feedback_sequence}")

    # Run agents until HITL interrupt
    for _ in graph.stream(initial_state, config, stream_mode="values"):
        pass

    fb_idx = 0
    round_num = 0

    while True:
        snapshot = graph.get_state(config)
        if not snapshot.next:
            break

        round_num += 1
        draft = snapshot.values.get("draft_report", "")

        feedback = feedback_sequence[fb_idx] if fb_idx < len(feedback_sequence) else "approve"
        fb_idx += 1

        print(f"\n--- HITL Round {round_num} ---")
        print(f"Draft preview: {draft[:300]}..." if len(draft) > 300 else f"Draft: {draft}")
        print(f"Simulated feedback: '{feedback}'")

        graph.update_state(config, {"human_feedback": feedback})

        for _ in graph.stream(None, config, stream_mode="values"):
            pass

    final = graph.get_state(config).values.get("final_report", "No final report.")

    print(f"\n[TEST RESULT] Final report length: {len(final)} chars")
    print("\n" + "=" * 60)
    print("FINAL REPORT")
    print("=" * 60)
    print(final)
    print("=" * 60)
    return final


print("run_workflow_test() defined.")
# Out:
# run_workflow_test() defined.

# %% [markdown]
# ---
# # Test Cases
#
# Five test cases demonstrating different HITL scenarios:
#
# | # | Topic | HITL Scenario |
# |---|-------|---------------|
# | TC-01 | History of the World Wide Web | Direct approval |
# | TC-02 | Benefits of renewable energy | One revision, then approval |
# | TC-03 | How quantum computing works | Direct approval (alt keyword) |
# | TC-04 | AI impact on employment | Two revisions, then approval |
# | TC-05 | Microbiome & human health | Direct approval (different domain) |

# %%
# ── TC-01: Direct Approval ────────────────────────────────────────────────────
# Demonstrates the happy-path: the first draft is accepted without any revisions.

result_tc01 = run_workflow_test(
    user_request="The history and evolution of the World Wide Web",
    feedback_sequence=["approve"],
    test_name="TC-01: Direct Approval"
)
# Out:
# ************************************************************
#   TC-01: Direct Approval
# ************************************************************
#
# Topic: The history and evolution of the World Wide Web
# Planned feedback sequence: ['approve']
#
# =======================================================
# [Researcher Agent] Gathering information...
# =======================================================
#   -> web_search: 'history and evolution of the World Wide Web'
#   -> wikipedia_search: 'World Wide Web'
#   [Researcher] Research complete.
#
# =======================================================
# [Writer Agent] Creating initial report...
# =======================================================
#   [Writer] Draft ready.
#
# --- HITL Round 1 ---
# Draft preview: # Research Report: The History and Evolution of the World Wide Web
#
# ## Executive Summary
# The World Wide Web (WWW) has revolutionized the way information is shared and accessed globally since its inception in 1989. This report explores the history and evolution of the Web, highlighting key technologi...
# Simulated feedback: 'approve'
#
#   [Human Review] Report APPROVED. Finalising...
#
# [TEST RESULT] Final report length: 4254 chars
#
# ============================================================
# FINAL REPORT
# ============================================================
# # Research Report: The History and Evolution of the World Wide Web
#
# ## Executive Summary
# The World Wide Web (WWW) has revolutionized the way information is shared and accessed globally since its inception in 1989. This report explores the history and evolution of the Web, highlighting key technologies, historical milestones, and its profound impact on society. It also examines the future trajectory of the Web as it continues to evolve in response to technological advancements and user needs.
#
# ## Key Findings
# - The World Wide Web was invented by Tim Berners-Lee in 1989 and became publicly accessible in 1993, fundamentally changing global communication and information sharing.
# - The Web has evolved through distinct phases: Web 1.0 (static content), Web 2.0 (interactive and user-generated content), Web 3.0 (semantic web), and anticipates future stages such as Web 4.0 (intelligent web) and Web 5.0 (emotional interactions).
# - Key technologies underpinning the Web include HTTP, URLs, HTML, and web browsers, which have facilitated the growth and accessibility of online content.
# - The impact of the Web is evident across various sectors, including education, commerce, and entertainment, making it a critical component of modern society.
#
# ## Detailed Analysis
# The World Wide Web, often simply referred to as the Web, is a system that allows users to access and share information via the Internet. Tim Berners-Lee, a British computer scientist, conceptualized the Web in 1989 while working at CERN. His vision was to create a universal linked information system that would enable seamless sharing of documents and media. The first version of HTML was published in 1991, and the Web was opened to the public in 1993, marking the beginning of a new era in digital communication.
#
# The evolution of the Web can be categorized into several distinct phases. Web 1.0, the initial stage, was characterized by static web pages that provided limited interactivity, primarily serving as read-only content. As technology advanced, Web 2.0 emerged, introducing dynamic content and user-generated contributions. This phase saw the rise of social media platforms, blogs, and collaborative tools, fundamentally changing how users interacted with online content. Currently, we are witnessing the transition towards Web 3.0, often referred to as the semantic web, which emphasizes data interoperability and machine understanding, enabling more intelligent search and data retrieval processes.
#
# The impact of the World Wide Web on society has been profound. It has transformed communication, commerce, education, and entertainment, becoming the dominant platform for information systems worldwide. The Web has democratized access to information, allowing individuals from diverse backgrounds to share knowledge and resources. Furthermore, it has facilitated the growth of e-commerce, enabling businesses to reach global markets and consumers to access a wider range of products and services than ever before.
#
# As we look to the future, the Web continues to evolve in response to technological advancements and changing user expectations. Ongoing developments in web standards and protocols aim to enhance security, accessibility, and user engagement. Concepts such as Web 4.0, which envisions a more intelligent web integrated with artificial intelligence, and Web 5.0, which may involve emotional and intuitive interactions, suggest that the Web's evolution is far from over.
#
# ## Conclusions & Implications
# The history and evolution of the World Wide Web illustrate a remarkable journey from a simple linked information system to a complex, interactive platform that shapes our daily lives. Understanding this evolution is crucial for recognizing the future trajectory of digital experiences and the ongoing transformation of society. As the Web continues to develop, it will be essential for stakeholders, including technologists, policymakers, and educators, to adapt and innovate in order to harness its full potential while addressing challenges such as security, privacy, and accessibility. The future of the Web holds exciting possibilities, and its continued evolution will undoubtedly influence how we communicate, learn, and interact in the years to come.
# ============================================================

# %%
# ── TC-02: One Revision Then Approval ────────────────────────────────────────
# Demonstrates the reviewer requesting a change before approving.
# The writer re-runs with the feedback, produces a revised draft, which is
# then approved in round 2.

result_tc02 = run_workflow_test(
    user_request="Benefits and challenges of renewable energy sources",
    feedback_sequence=[
        "Please add specific statistics on solar and wind capacity growth, "
        "and include a brief comparison of costs versus fossil fuels.",
        "approve"
    ],
    test_name="TC-02: One Revision Then Approval"
)
# Out:
# ************************************************************
#   TC-02: One Revision Then Approval
# ************************************************************
#
# Topic: Benefits and challenges of renewable energy sources
# Planned feedback sequence: ['Please add specific statistics on solar and wind capacity growth, and include a brief comparison of costs versus fossil fuels.', 'approve']
#
# =======================================================
# [Researcher Agent] Gathering information...
# =======================================================
#   -> web_search: 'Benefits and challenges of renewable energy sources 2023'
#   -> wikipedia_search: 'Renewable energy'
#   [Researcher] Research complete.
#
# =======================================================
# [Writer Agent] Creating initial report...
# =======================================================
#   [Writer] Draft ready.
#
# --- HITL Round 1 ---
# Draft preview: # Research Report: Benefits and Challenges of Renewable Energy Sources
#
# ## Executive Summary
# This report provides a comprehensive analysis of the benefits and challenges associated with renewable energy sources. As the world grapples with the effects of climate change and the depletion of fossil fue...
# Simulated feedback: 'Please add specific statistics on solar and wind capacity growth, and include a brief comparison of costs versus fossil fuels.'
#
#   [Human Review] Revision #1 requested.
#
# =======================================================
# [Writer Agent] Revising report (revision #1)...
# =======================================================
#   [Writer] Draft ready.
#
# --- HITL Round 2 ---
# Draft preview: # Research Report: Benefits and Challenges of Renewable Energy Sources
#
# ## Executive Summary
# This report provides a comprehensive analysis of the benefits and challenges associated with renewable energy sources. As the world grapples with the effects of climate change and the depletion of fossil fue...
# Simulated feedback: 'approve'
#
#   [Human Review] Report APPROVED. Finalising...
#
# [TEST RESULT] Final report length: 4900 chars
#
# ============================================================
# FINAL REPORT
# ============================================================
# # Research Report: Benefits and Challenges of Renewable Energy Sources
#
# ## Executive Summary
# This report provides a comprehensive analysis of the benefits and challenges associated with renewable energy sources. As the world grapples with the effects of climate change and the depletion of fossil fuels, renewable energy has emerged as a viable alternative. This report outlines the environmental, economic, and security benefits of renewable energy, while also addressing the challenges that hinder its widespread adoption. The findings indicate that while renewable energy presents significant advantages, overcoming the associated challenges is essential for achieving a sustainable energy future.
#
# ## Key Findings
# - Renewable energy significantly reduces greenhouse gas emissions and improves air quality, contributing to public health and climate change mitigation.
# - The cost of renewable energy technologies has decreased dramatically, with solar and wind now often being the cheapest sources of new electricity generation. For instance, the levelized cost of electricity (LCOE) for solar has dropped by approximately 89% since 2010, while onshore wind has seen a reduction of about 70%.
# - Intermittency and infrastructure needs pose significant challenges to the reliability and integration of renewable energy into existing energy systems.
# - Political and economic barriers, including fossil fuel subsidies, hinder the growth of renewable energy deployment.
# - Current trends indicate that renewable energy could account for over 45% of global electricity generation by 2030, driven by technological advancements and increased climate awareness. As of 2024, renewable energy sources accounted for over 30% of global electricity generation, with solar and wind capacity growing at an annual rate of approximately 20% and 15%, respectively.
#
# ## Detailed Analysis
# Renewable energy, encompassing sources such as solar, wind, hydropower, bioenergy, and geothermal power, is derived from natural resources that are replenished on a human timescale. The transition to renewable energy is primarily motivated by the need to mitigate climate change through the reduction of greenhouse gas emissions. Compared to fossil fuels, renewable energy sources produce significantly lower emissions, which not only helps combat climate change but also leads to improved air quality and public health outcomes. The economic landscape is also shifting, as the costs associated with renewable technologies have plummeted over the last decade. Solar and wind energy, in particular, have become the most cost-effective sources of new electricity generation in many regions, fostering job creation in manufacturing, installation, and maintenance.
#
# Despite these advantages, renewable energy faces several challenges that must be addressed to facilitate its widespread adoption. One of the most significant challenges is the intermittency and reliability of renewable sources. Solar and wind energy production is highly dependent on weather conditions, which can lead to fluctuations in energy supply. This variability necessitates the development of advanced energy storage solutions and a robust energy infrastructure capable of accommodating these sources. Upgrading existing energy infrastructure is critical to connect remote energy generation sites to urban demand centers, ensuring a stable and reliable energy supply.
#
# Moreover, the land use and environmental concerns associated with renewable energy installations cannot be overlooked. The deployment of renewable technologies can lead to land use conflicts and habitat disruption, particularly in ecologically sensitive areas. Additionally, the extraction of minerals required for renewable technologies can have detrimental environmental impacts. Political and economic barriers, such as fossil fuel subsidies and lobbying by traditional energy providers, further complicate the transition to renewable energy. Local opposition to renewable projects can also pose significant challenges, as communities may resist changes to their landscapes or fear potential negative impacts.
#
# ## Conclusions & Implications
# In conclusion, renewable energy sources offer a promising solution to the environmental and economic challenges posed by fossil fuels. The benefits of renewable energy, including reduced greenhouse gas emissions, improved air quality, and job creation, are substantial. However, significant challenges remain, particularly in terms of infrastructure, reliability, and political will. Addressing these challenges is crucial for realizing the full potential of renewable energy and achieving global climate goals. As the world moves towards a more sustainable energy future, it is imperative that stakeholders—governments, businesses, and communities—collaborate to overcome these obstacles and accelerate the transition to renewable energy sources.
# ============================================================

# %%
# ── TC-03: Approval With Alternative Keyword ─────────────────────────────────
# Shows that the system recognises synonyms for approval
# ('looks good' is treated the same as 'approve').

result_tc03 = run_workflow_test(
    user_request="How does quantum computing work and what are its potential applications?",
    feedback_sequence=["looks good"],
    test_name="TC-03: Approval With Alternative Keyword ('looks good')"
)
# Out:
# ************************************************************
#   TC-03: Approval With Alternative Keyword ('looks good')
# ************************************************************
#
# Topic: How does quantum computing work and what are its potential applications?
# Planned feedback sequence: ['looks good']
#
# =======================================================
# [Researcher Agent] Gathering information...
# =======================================================
#   -> wikipedia_search: 'Quantum computing'
#   -> web_search: 'How does quantum computing work and its potential applications 2023'
#   -> wikipedia_search: 'Quantum computing'
#   -> web_search: 'Quantum computing applications 2023'
#   -> wikipedia_search: 'Quantum computing applications'
#   -> web_search: 'Quantum computing technology 2023'
#   -> wikipedia_search: 'Quantum computing principles'
#   -> web_search: 'Quantum computing advancements 2023'
#   [Researcher] Research complete.
#
# =======================================================
# [Writer Agent] Creating initial report...
# =======================================================
#   [Writer] Draft ready.
#
# --- HITL Round 1 ---
# Draft preview: # Research Report: How Does Quantum Computing Work and What Are Its Potential Applications?
#
# ## Executive Summary
# Quantum computing represents a paradigm shift in computational technology, utilizing the principles of quantum mechanics to process information in ways that classical computers cannot. B...
# Simulated feedback: 'looks good'
#
#   [Human Review] Report APPROVED. Finalising...
#
# [TEST RESULT] Final report length: 4980 chars
#
# ============================================================
# FINAL REPORT
# ============================================================
# # Research Report: How Does Quantum Computing Work and What Are Its Potential Applications?
#
# ## Executive Summary
# Quantum computing represents a paradigm shift in computational technology, utilizing the principles of quantum mechanics to process information in ways that classical computers cannot. By harnessing the unique properties of qubits—such as superposition, entanglement, and quantum interference—quantum computers can perform complex calculations exponentially faster than their classical counterparts. As of 2023, significant advancements have been made in the field, leading to practical applications across various industries, including cryptography, pharmaceuticals, finance, logistics, artificial intelligence, and material science. The economic impact of quantum computing is projected to be substantial, with potential value increases reaching up to $1.3 trillion by 2035.
#
# ## Key Findings
# - Quantum computing utilizes qubits, which can exist in multiple states simultaneously, enabling parallel processing and complex calculations.
# - Major advancements in error correction techniques have improved the reliability of quantum computations, accelerating the timeline for practical applications.
# - Quantum computing has transformative potential in sectors such as cryptography, healthcare, finance, supply chain management, AI, and material science.
# - The economic impact of quantum computing could lead to a combined value increase of up to $1.3 trillion across various industries by 2035.
#
# ## Detailed Analysis
# Quantum computing operates on the fundamental principles of quantum mechanics, which govern the behavior of subatomic particles. The core unit of quantum computing, the qubit, differs from classical bits by being able to exist in a state of superposition, where it can represent both 0 and 1 simultaneously. This characteristic allows quantum computers to process vast amounts of data in parallel, significantly enhancing computational speed and efficiency. Additionally, the phenomenon of entanglement enables qubits to be interconnected in such a way that the state of one qubit can instantaneously affect another, regardless of the distance separating them. This property is particularly useful for complex calculations and algorithms, as it allows for the manipulation of multiple qubits simultaneously.
#
# As of 2023, the landscape of quantum computing has evolved considerably, with major tech companies like IBM leading the charge in developing quantum systems that can outperform classical supercomputers in specific tasks. The focus has shifted from merely increasing the number of qubits to enhancing the practical applicability of quantum systems. Innovations in error correction techniques have played a crucial role in this transition, improving the reliability of quantum computations and potentially shortening the timeline for large-scale quantum systems by 5 to 10 years. Concurrently, researchers are investigating the integration of quantum computing with artificial intelligence, which could further enhance predictive capabilities and problem-solving in complex systems.
#
# The potential applications of quantum computing are vast and varied. In the field of cryptography, quantum key distribution could provide unprecedented levels of security, making it nearly impossible for unauthorized entities to intercept communications. In pharmaceuticals and healthcare, quantum computers can simulate molecular interactions, expediting drug discovery and enabling personalized medicine. The financial services sector stands to benefit from quantum computing through optimized portfolio management, risk assessment, and fraud detection. Furthermore, quantum algorithms can revolutionize supply chain logistics by optimizing routing and reducing costs. In artificial intelligence, quantum computing can enhance machine learning algorithms, leading to faster data processing and improved model training. Lastly, quantum simulations can facilitate the discovery of new materials with desirable properties, impacting industries ranging from electronics to energy.
#
# ## Conclusions & Implications
# Quantum computing is still in its nascent stages but promises to revolutionize various sectors by enabling computations that were previously thought to be infeasible. As research progresses and technology matures, the applications of quantum computing could lead to significant breakthroughs in science and technology, enhancing computational capabilities and transforming industries. The economic implications are profound, with estimates suggesting that industries such as automotive, chemicals, financial services, and life sciences could collectively see a value increase of up to $1.3 trillion by 2035. As the focus shifts from theoretical exploration to practical implementation, quantum computing emerges as a critical area for future investment and development, with the potential to reshape the technological landscape in the coming decades.
# ============================================================

# %%
# ── TC-04: Multiple Revisions ─────────────────────────────────────────────────
# Demonstrates two successive revision cycles before final approval.
# Round 1: reviewer asks for a healthcare-specific section.
# Round 2: reviewer asks to deepen that section.
# Round 3: reviewer approves.

result_tc04 = run_workflow_test(
    user_request="Impact of artificial intelligence on employment and the job market",
    feedback_sequence=[
        "The executive summary is too long. Please shorten it to 2 sentences "
        "and add a dedicated section on AI's impact in the healthcare job market.",
        "The healthcare section needs more depth — please add two concrete examples "
        "of AI diagnostic tools currently used in hospitals.",
        "approve"
    ],
    test_name="TC-04: Multiple Revisions (2 rounds) Then Approval"
)
# Out:
# ************************************************************
#   TC-04: Multiple Revisions (2 rounds) Then Approval
# ************************************************************
#
# Topic: Impact of artificial intelligence on employment and the job market
# Planned feedback sequence: ["The executive summary is too long. Please shorten it to 2 sentences and add a dedicated section on AI's impact in the healthcare job market.", 'The healthcare section needs more depth — please add two concrete examples of AI diagnostic tools currently used in hospitals.', 'approve']
#
# =======================================================
# [Researcher Agent] Gathering information...
# =======================================================
#   -> web_search: 'Impact of artificial intelligence on employment and the job market 202'
#   -> wikipedia_search: 'Impact of artificial intelligence on employment'
#   [Researcher] Research complete.
#
# =======================================================
# [Writer Agent] Creating initial report...
# =======================================================
#   [Writer] Draft ready.
#
# --- HITL Round 1 ---
# Draft preview: # Research Report: Impact of Artificial Intelligence on Employment and the Job Market
#
# ## Executive Summary
# This report examines the multifaceted impact of artificial intelligence (AI) on employment and the job market, highlighting both the potential for job displacement and the creation of new oppo...
# Simulated feedback: 'The executive summary is too long. Please shorten it to 2 sentences and add a dedicated section on AI's impact in the healthcare job market.'
#
#   [Human Review] Revision #1 requested.
#
# =======================================================
# [Writer Agent] Revising report (revision #1)...
# =======================================================
#   [Writer] Draft ready.
#
# --- HITL Round 2 ---
# Draft preview: # Research Report: Impact of Artificial Intelligence on Employment and the Job Market
#
# ## Executive Summary
# This report examines the impact of artificial intelligence (AI) on employment, highlighting both the potential for job displacement and the creation of new opportunities. As AI technologies ev...
# Simulated feedback: 'The healthcare section needs more depth — please add two concrete examples of AI diagnostic tools currently used in hospitals.'
#
#   [Human Review] Revision #2 requested.
#
# =======================================================
# [Writer Agent] Revising report (revision #2)...
# =======================================================
#   [Writer] Draft ready.
#
# --- HITL Round 3 ---
# Draft preview: # Research Report: Impact of Artificial Intelligence on Employment and the Job Market
#
# ## Executive Summary
# This report examines the impact of artificial intelligence (AI) on employment, highlighting both the potential for job displacement and the creation of new opportunities. As AI technologies ev...
# Simulated feedback: 'approve'
#
#   [Human Review] Report APPROVED. Finalising...
#
# [TEST RESULT] Final report length: 6243 chars
#
# ============================================================
# FINAL REPORT
# ============================================================
# # Research Report: Impact of Artificial Intelligence on Employment and the Job Market
#
# ## Executive Summary
# This report examines the impact of artificial intelligence (AI) on employment, highlighting both the potential for job displacement and the creation of new opportunities. As AI technologies evolve, they are expected to disrupt a significant portion of the workforce, particularly in roles characterized by repetitive tasks, while also transforming sectors such as healthcare.
#
# ## Key Findings
# - AI is projected to affect nearly 40% of all jobs, with a significant risk of job displacement in roles involving repetitive tasks.
# - Approximately 44% of workers' skills will be disrupted by AI advancements between 2023 and 2028, necessitating a shift in skill development.
# - Jobs requiring human creativity and emotional intelligence, such as those in healthcare and education, are less likely to be automated.
# - The introduction of AI can improve workplace safety but may also introduce new hazards and ethical concerns.
# - The long-term impact of AI on employment remains debated, with potential for both job losses and new opportunities, particularly in technology sectors.
#
# ## Impact of AI on the Healthcare Job Market
# The healthcare sector is experiencing a unique transformation due to AI integration. While roles that require human empathy and complex decision-making, such as doctors and nurses, are less likely to be automated, AI technologies are increasingly being utilized to enhance efficiency and patient care.
#
# For instance, AI-driven diagnostic tools such as IBM Watson Health and Google's DeepMind Health are currently being utilized in hospitals to assist healthcare professionals. IBM Watson Health analyzes vast amounts of medical literature and patient data to provide evidence-based treatment recommendations, thereby supporting clinicians in making informed decisions. Similarly, DeepMind Health has developed algorithms that can accurately detect eye diseases from retinal scans, allowing for earlier intervention and improved patient outcomes.
#
# However, the reliance on AI in healthcare also raises ethical concerns regarding patient privacy and the potential for biased algorithms affecting treatment outcomes. As a result, healthcare professionals must adapt by acquiring new skills that complement AI technologies, ensuring they can work effectively alongside these tools.
#
# ## Detailed Analysis
# The rise of artificial intelligence is reshaping the job market in profound ways. According to a recent analysis by the International Monetary Fund (IMF), nearly 40% of jobs are at risk of disruption due to AI technologies. This disruption is particularly pronounced in roles that involve repetitive tasks, such as data entry and customer service, which are increasingly being automated. The IMF's managing director, Kristalina Georgieva, has highlighted concerns that AI could exacerbate existing inequalities in the job market, as those in lower-skilled positions may find it more challenging to transition to new roles.
#
# As AI continues to evolve, the skills required in the workforce are also changing. Predictions indicate that by 2028, 44% of workers will experience significant disruptions to their skill sets due to advancements in AI. This shift emphasizes the importance of reskilling and upskilling, as workers must adapt to new demands in the labor market. While jobs that require complex human interaction and creativity—such as those in healthcare, education, and the creative industries—are less likely to be automated, there is a pressing need for workers to develop skills that align with the future job landscape.
#
# The introduction of AI in the workplace also has implications for safety and health. On the positive side, AI can enhance workplace safety by automating hazardous tasks and predicting potential risks, thereby reducing the likelihood of accidents. However, the integration of AI can also lead to new challenges, including increased monitoring of employees and potential biases in decision-making algorithms. Employers must navigate these complexities to ensure a safe and equitable work environment.
#
# The long-term perspectives on AI's impact on employment remain contested. While some researchers predict significant job losses, others argue that AI may create new job opportunities, particularly in technology-driven sectors. The recent layoffs in the tech industry in 2023, attributed to the rise of AI technologies, illustrate the shifting workforce needs and the potential for disruption. As the landscape evolves, it is crucial for stakeholders to remain vigilant and proactive in addressing the challenges and opportunities presented by AI.
#
# ## Conclusions & Implications
# The impact of artificial intelligence on employment and the job market is complex and multifaceted. While AI has the potential to enhance productivity and workplace safety, it also poses risks of job displacement and increased inequality. To navigate this changing landscape, workers must focus on developing skills that are less susceptible to automation, such as critical thinking, creativity, and interpersonal skills. Employers are encouraged to embrace AI technologies while considering their ethical implications and the potential impacts on their workforce. Policymakers play a critical role in addressing the inequalities that may arise from AI adoption, ensuring that the benefits of technological advancements are equitably distributed across society. The ongoing evolution of AI will continue to shape the labor market, necessitating a collaborative approach to reskilling and adapting to new job requirements.
#
# ### Recommendations for Workers and Employers
# - **Reskilling and Upskilling**: Workers should focus on developing skills that are less likely to be automated, such as critical thinking, creativity, and interpersonal skills.
# - **Embrace Technology**: Employers should leverage AI to enhance productivity while also considering the ethical implications and potential impacts on their workforce.
# - **Policy Considerations**: Policymakers should address the inequalities that may arise from AI adoption, ensuring that the benefits of technology are distributed equitably across society.
# ============================================================

# %%
# ── TC-05: Different Domain (Biology / Medicine) ──────────────────────────────
# Verifies the workflow generalises beyond technology topics.

result_tc05 = run_workflow_test(
    user_request="The human microbiome: its role in health and disease",
    feedback_sequence=["accepted"],
    test_name="TC-05: Different Domain (Biology/Medicine)"
)

print("\nAll 5 test cases completed successfully.")
# Out:
# ************************************************************
#   TC-05: Different Domain (Biology/Medicine)
# ************************************************************
#
# Topic: The human microbiome: its role in health and disease
# Planned feedback sequence: ['accepted']
#
# =======================================================
# [Researcher Agent] Gathering information...
# =======================================================
#   -> web_search: 'The human microbiome role in health and disease 2023'
#   -> wikipedia_search: 'Human microbiome'
#   [Researcher] Research complete.
#
# =======================================================
# [Writer Agent] Creating initial report...
# =======================================================
#   [Writer] Draft ready.
#
# --- HITL Round 1 ---
# Draft preview: # Research Report: The Human Microbiome: Its Role in Health and Disease
#
# ## Executive Summary
# The human microbiome is a complex ecosystem of microorganisms residing in various parts of the human body, significantly influencing health and disease. This report synthesizes findings from recent research...
# Simulated feedback: 'accepted'
#
#   [Human Review] Report APPROVED. Finalising...
#
# [TEST RESULT] Final report length: 4594 chars
#
# ============================================================
# FINAL REPORT
# ============================================================
# # Research Report: The Human Microbiome: Its Role in Health and Disease
#
# ## Executive Summary
# The human microbiome is a complex ecosystem of microorganisms residing in various parts of the human body, significantly influencing health and disease. This report synthesizes findings from recent research, including insights from the Human Microbiome Project (HMP), to highlight the microbiome's role in health, its implications for disease, and potential therapeutic applications. Understanding the microbiome's composition and function is crucial for developing personalized medicine strategies and public health policies aimed at improving health outcomes.
#
# ## Key Findings
# - The human microbiome consists of a diverse array of microorganisms, including bacteria, archaea, fungi, and viruses, which play essential roles in digestion, immune regulation, and overall health.
# - Alterations in the microbiome have been linked to various diseases, including obesity, diabetes, inflammatory bowel disease, and mental health disorders.
# - Therapeutic strategies such as probiotics, prebiotics, and fecal microbiota transplantation (FMT) are being explored to restore microbiome balance and improve health outcomes.
# - Personalized medicine approaches are emerging, where individual microbiome profiles could inform tailored treatments for various health conditions.
# - Public health policies are increasingly focusing on the importance of diet and lifestyle in maintaining a healthy microbiome, emphasizing education and prevention strategies.
#
# ## Detailed Analysis
# The human microbiome encompasses trillions of microorganisms that inhabit the human body, primarily within the gastrointestinal tract. This diverse community includes both beneficial and harmful species, contributing to a delicate balance that is essential for maintaining health. The Human Microbiome Project, initiated in 2007, has significantly advanced our understanding of this complex ecosystem by employing cutting-edge techniques such as metagenomics and whole genome sequencing. These advancements have allowed researchers to characterize microbial communities and their functional roles in human physiology.
#
# Recent studies have highlighted the microbiome's influence on a range of health conditions. For instance, alterations in microbial composition have been associated with obesity, diabetes, and inflammatory bowel disease, suggesting that the microbiome may play a role in metabolic regulation and immune response. Additionally, emerging research indicates that the gut microbiome may impact mental health, linking gut health to conditions such as anxiety and depression. This dual nature of the microbiome—where beneficial microorganisms coexist with potentially harmful ones—underscores the need for a nuanced understanding of its impact on health.
#
# Therapeutic applications of microbiome modulation are gaining traction in clinical settings. Probiotics and prebiotics are being investigated for their potential to restore microbial balance and improve health outcomes. Fecal microbiota transplantation (FMT) has shown promise in treating recurrent Clostridium difficile infections and is being explored for other conditions. These interventions aim to harness the beneficial effects of the microbiome, offering new avenues for treatment that could complement traditional medical approaches.
#
# As research progresses, the concept of personalized medicine is becoming increasingly relevant. Individual microbiome profiles could inform tailored treatment strategies, enhancing the efficacy of interventions based on a person's unique microbial composition. Furthermore, public health initiatives are recognizing the importance of the microbiome in nutrition and disease prevention, advocating for education on dietary choices and lifestyle modifications that promote a healthy microbiome.
#
# ## Conclusions & Implications
# The human microbiome is a vital component of human health, influencing various physiological processes and disease mechanisms. The insights gained from the Human Microbiome Project and ongoing research underscore the importance of understanding microbial communities in the context of health and disease. As we continue to explore the therapeutic potential of microbiome modulation and the implications for personalized medicine, it is essential to integrate this knowledge into public health policies. Promoting awareness of the microbiome's role in health can empower individuals to make informed choices that support their well-being, ultimately leading to improved health outcomes on a broader scale.
# ============================================================
#
# All 5 test cases completed successfully.
